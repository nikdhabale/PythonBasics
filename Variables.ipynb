# %% [markdown]
# Variables :
# 1. Reference or pointer to an object
# 2. Value to variable assigned with assiegnment operator (=)

# %%
Var_name = "Apple"
print(Var_name)
# Out:
# Apple

# %%
x = 1
print(x+1)
# Out:
# 2

# %%
a,b,c = 5,10,15
print(a,b,c)
print(a+b+c)
# Out:
# 5 10 15
# 30
