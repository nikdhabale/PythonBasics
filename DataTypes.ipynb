# %% [markdown]
# Data Type:
# 1. It is a classification that specifies the type of value a
# variable can hold.
# 2. We can check data type using type() function

# %%
fruit = "Banana"
type(fruit)
# Out:
# str

# %%
Num = 3.14
type(Num)
# Out:
# float

# %%
bool_var = True
type(bool_var)
# Out:
# bool

# %%
value = 35
type(value)
# Out:
# int

# %% [markdown]
# Basic data Types
# 1. Numeric: Integer, Float, Complex
# 2. Sequence: String, List, Tuple
# 3. Dictionary
# 4. Set
# 5. Boolean
# 6. Binary: Bytes, Bytearray, Memoryview
