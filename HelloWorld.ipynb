# %%
print("hello world")
# Out:
# hello world

# %%
name = input("Enter your name: ")
print("Hello, " + name + "!")
# Out:
# Hello, Nikhil!

# %%
strName = input("Enter a string: ")
print("You entered: " + strName)    
strName.isprintable()
# Out:
# You entered: hello
# True
